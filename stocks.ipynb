# %%
import pandas_datareader.data as web
import datetime

# %%
iex_token='Tpk_c844fe97a248420e9e6b06919ac2fcb0'
stock = 'TSLA'
period = '1m'

url = 'https://sandbox.iexapis.com/stable/stock/%s/chart/%s?token=%s'%(stock,period,iex_token)

# %%
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 27)
df = web.DataReader(['F','MSFT'], 'yahoo', start, end)
df.head()
# Out:
# Attributes   High               Low  ...      Volume  Adj Close
# Symbols         F       MSFT      F  ...        MSFT          F       MSFT
# Date                                 ...
# 2016-01-04  14.00  54.799999  13.75  ...  53778000.0  11.204133  50.877312
# 2016-01-05  14.00  55.389999  13.51  ...  34079700.0  11.003628  51.109421
# 2016-01-06  13.56  54.400002  13.05  ...  39518900.0  10.514400  50.181000
# 2016-01-07  13.04  53.490002  12.60  ...  56564900.0  10.185575  48.435574
# 2016-01-08  13.10  53.279999  12.50  ...  48754000.0  10.057251  48.584122
#
# [5 rows x 12 columns]
